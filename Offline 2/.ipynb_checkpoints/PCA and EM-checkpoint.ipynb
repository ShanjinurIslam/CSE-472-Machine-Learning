# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pow,sqrt

np.random.seed(40)

# %%
file = open('data.txt')

lines = file.readlines()

dataset = []

for line in lines:
    var = line.split()
    var = np.array([float(x) for x in var])
    dataset.append(var)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (500, 100)

# %% [markdown]
# # PCA and Dimentionality Reduction

# %%
mean_arr = np.array([np.mean(dataset[:,i]) for i in range(dataset.shape[1])])

# %%
co_var_matrix = np.zeros((dataset.shape[1],dataset.shape[1]))
dataset_len = len(dataset)

for i in range(dataset.shape[1]):
    for j in range(dataset.shape[1]):
        X = dataset[:,i]
        Y = dataset[:,j]
        
        sum = 0
        
        for k in range(dataset_len):
            sum += (X[k]-mean_arr[i])*(Y[k]-mean_arr[j])
        
        co_var_matrix[i][j] = sum/(dataset_len-1)

# %%
eigen_value,eigen_vector = np.linalg.eig(co_var_matrix)

# %%
max_index = np.argmax(eigen_value)
feature_vector1 = eigen_vector.transpose()[max_index]

second_max = np.sort(eigen_value)[-2]
itemindex = np.where(eigen_value==second_max)
feature_vector2 = eigen_vector.transpose()[itemindex][0]

# %%
X = np.dot(feature_vector1,dataset.transpose())
Y = np.dot(feature_vector2,dataset.transpose())

final_dataset = np.vstack((X,Y)).transpose()
final_dataset
# Out:
# array([[ 5.65936625,  2.8524277 ],
#        [ 5.78642686, -0.66910475],
#        [ 7.90739721,  3.30726583],
#        [ 5.19954652, -0.68514422],
#        [ 7.27061957,  2.40680085],
#        [ 2.93798157,  2.79564182],
#        [ 1.52310202,  2.39733967],
#        [ 3.49197159, -1.90763307],
#        [ 0.71729502,  1.70803674],
#        [-2.42870648,  2.27434851],
#        [ 3.4296446 , -1.54804849],
#        [ 0.75535004,  2.32556923],
#        [ 1.3336766 ,  4.70757368],
#        [ 7.5836478 ,  3.69570323],
#        [ 4.27414374,  0.06842291],
#        [ 7.87837008,  2.93261955],
#        [ 2.04856437,  0.8508677 ],
#        [ 5.26873989,  1.15056285],
#        [ 6.05450296,  2.89116741],
#        [ 3.0107772 ,  2.60352519],
#        [ 2.39742342,  4.65555469],
#        [ 4.04504066, -0.99596849],
#        [ 0.43214786,  3.195676  ],
#        [ 5.44811413,  3.26294448],
#        [ 6.41537512,  3.34699963],
#        [-1.39735105,  1.53006194],
#        [ 6.73359291,  2.78487472],
#        [ 9.08685502,  2.57330935],
#        [ 9.06592492,  2.07509701],
#        [ 8.19153686,  4.29887323],
#        [-0.16218195,  3.66279035],
#        [ 0.98050057,  1.88356949],
#        [ 3.15754582,  2.7269437 ],
#        [ 2.05331694, -1.09738964],
#        [ 1.81828746,  3.99197641],
#        [ 0.3329531 ,  1.06573335],
#        [ 7.44970294,  2.31404309],
#        [ 0.4473902 ,  1.12252842],
#        [ 9.30942482,  3.99538302],
#        [-1.45754591,  2.99265536],
#        [ 7.25494806,  2.49310686],
#        [ 2.77068546, -1.96719564],
#        [ 4.3392086 ,  0.33026345],
#        [ 1.83506027, -3.02299629],
#        [ 3.06677757,  1.86730304],
#        [ 3.83255083, -1.54811016],
#        [-0.62405595,  1.26771469],
#        [-0.33222472,  4.11852135],
#        [ 3.26816308,  4.77582925],
#        [ 3.70310637,  2.24157326],
#        [ 4.11089938, -0.66685626],
#        [ 0.14565437,  4.05504645],
#        [ 4.05932883, -0.50753055],
#        [-1.04794769,  3.8589179 ],
#        [ 6.03560957,  4.10336925],
#        [-1.69020693,  1.19805712],
#        [ 6.53178688,  3.01952827],
#        [ 0.56343547,  3.27847628],
#        [ 0.19690338,  2.46229559],
#        [-0.44615017,  1.12078151],
#        [-0.89873935,  4.10605725],
#        [ 3.0926234 , -1.29309228],
#        [-0.05351888,  3.48595803],
#        [ 1.43579096,  4.45411079],
#        [ 7.33092383,  1.93404856],
#        [ 3.12806179, -2.17077183],
#        [ 3.05357353, -0.42464215],
#        [-0.35124245,  3.43519473],
#        [ 3.8512087 ,  3.63480908],
#        [ 3.0601377 , -2.87428699],
#        [ 0.30044803,  1.20946871],
#        [ 0.88140143,  2.42892087],
#        [ 7.80441821,  0.37748741],
#        [ 8.05271896,  2.75675269],
#        [-1.54501429,  2.73483564],
#        [ 5.04991063, -2.03480529],
#        [ 4.43957566, -2.46017175],
#        [ 8.31020481,  1.37527485],
#        [ 6.75353763,  1.89161707],
#        [ 3.04299044, -2.64865027],
#        [ 8.2591048 ,  2.58498809],
#        [ 7.1236192 ,  3.59968416],
#        [ 0.88202826,  3.77901644],
#        [ 3.16180311,  2.5959723 ],
#        [ 7.12146438,  3.64137853],
#        [ 7.73485236,  0.64772924],
#        [ 2.89568864,  3.84936051],
#        [ 6.46726688,  3.46220739],
#        [ 3.27789508, -0.78081385],
#        [-0.88133332,  2.60665455],
#        [ 0.3564383 ,  1.33928277],
#        [ 2.75804718,  3.79037838],
#        [ 8.65770263,  4.13314244],
#        [ 0.33517012,  3.02579538],
#        [-2.00439192,  3.73177632],
#        [ 2.33640419,  3.97551645],
#        [ 6.30103968,  1.89102086],
#        [ 0.68086515,  2.53358319],
#        [-2.190025  ,  3.67293826],
#        [ 3.931675  , -2.2018535 ],
#        [ 8.51445583,  4.52614565],
#        [ 7.52369325,  4.24749966],
#        [ 0.73082607,  3.77703709],
#        [ 2.97830508,  0.92096045],
#        [ 2.29588463,  2.1453589 ],
#        [ 7.44799664,  4.58405707],
#        [ 0.63750907,  2.22502779],
#        [ 8.48514484,  3.14226537],
#        [ 8.19521846,  2.86865581],
#        [-0.02895834,  1.91879165],
#        [ 5.93016597,  3.25735229],
#        [ 4.38012474,  3.0084629 ],
#        [ 4.32072246, -1.79536098],
#        [-0.16158961,  1.92979733],
#        [ 1.63793889,  2.76015065],
#        [ 1.8891315 ,  3.2885158 ],
#        [ 9.01053973,  2.58660022],
#        [ 1.09051897,  1.42672456],
#        [ 4.87190397, -1.6996343 ],
#        [ 5.50500121, -1.26448533],
#        [ 0.36682683,  2.97010037],
#        [ 2.19573035,  3.30398304],
#        [-0.46131412,  4.48318324],
#        [ 1.1461105 ,  2.96326529],
#        [ 4.38979419, -3.77866545],
#        [ 3.10409387,  3.71332662],
#        [ 2.12898459,  2.12361139],
#        [ 0.60816494,  3.79543575],
#        [ 4.2317096 ,  0.20615612],
#        [ 6.16329504,  3.25350496],
#        [ 1.25428738,  4.11768888],
#        [ 6.84800164,  4.07960717],
#        [ 0.85348958,  1.47564636],
#        [ 0.47030694,  1.02621831],
#        [ 1.16826193,  2.00292432],
#        [ 2.90317058,  4.28283219],
#        [ 3.09469069,  2.8373688 ],
#        [ 5.47479483, -1.4514261 ],
#        [ 0.57891832,  3.32871902],
#        [ 3.73362855, -1.73067703],
#        [ 8.78209989,  2.51132604],
#        [ 0.27420883,  2.35298144],
#        [ 8.05316891,  3.33601344],
#        [ 1.74073103,  2.69308824],
#        [ 5.29044798,  3.18091548],
#        [ 3.72235128, -1.19577848],
#        [ 7.78654943,  3.94292308],
#        [ 2.67760858, -1.7253243 ],
#        [ 4.71343109,  2.39409565],
#        [ 1.62937527,  1.43720157],
#        [ 5.01917516, -1.28999561],
#        [ 6.19916693,  3.09938533],
#        [ 2.30146538,  1.41241091],
#        [ 8.0746904 ,  3.6126979 ],
#        [ 3.37061645, -2.18144016],
#        [ 3.9491794 , -1.39158759],
#        [ 8.38557887,  2.36292907],
#        [ 1.01856127,  2.09497151],
#        [ 3.41801526, -2.78806611],
#        [ 2.85104505,  2.67143149],
#        [ 5.73048977,  3.21246501],
#        [ 7.7553925 ,  4.05397462],
#        [ 3.83357416, -1.07143153],
#        [ 3.30430775,  2.37847869],
#        [ 2.34791583, -2.57522644],
#        [ 0.02601303,  2.90688741],
#        [ 6.01730133,  1.57439267],
#        [ 0.75935782,  2.06363292],
#        [ 6.42892719,  1.63247445],
#        [ 0.58085317,  3.14767808],
#        [ 2.83612623, -3.31514713],
#        [ 0.48358524,  4.31395542],
#        [ 3.73874324,  0.86131152],
#        [ 3.36675801,  0.61339453],
#        [ 0.69331629,  0.79017189],
#        [ 5.94716198,  3.22659259],
#        [ 0.12576346,  1.23205677],
#        [ 4.56533425, -0.15989341],
#        [ 3.72174062, -1.79233795],
#        [ 4.38786162, -2.18569053],
#        [ 3.54409189, -0.55858284],
#        [ 4.3808793 , -1.6009981 ],
#        [ 1.08733539,  1.33909752],
#        [ 8.52415718,  2.70973293],
#        [ 2.00331306,  1.52046144],
#        [ 2.67783084,  4.00219391],
#        [ 2.52450199,  0.94942981],
#        [ 7.54221993,  2.39504456],
#        [ 2.47245048, -2.5257363 ],
#        [ 8.18340139,  2.58165236],
#        [ 2.1754402 , -1.41409567],
#        [ 9.22061228,  3.29186665],
#        [ 6.59620318,  1.69330541],
#        [ 0.19431316,  0.39840789],
#        [-0.25069855,  2.62618755],
#        [ 7.29460364,  1.63674779],
#        [ 7.38271837,  3.50435013],
#        [ 7.21277459,  0.89490888],
#        [-1.27396237,  3.03608737],
#        [ 4.09137034, -1.22682535],
#        [ 9.34379883,  2.22442275],
#        [-0.47535217,  2.94860527],
#        [ 6.77918923,  1.85887918],
#        [ 4.00373443, -0.89900955],
#        [ 2.04841039, -1.48799664],
#        [ 4.61522674, -0.56210761],
#        [ 1.45124   ,  2.62261933],
#        [ 6.52410296,  4.08906332],
#        [ 0.26375417,  1.79239236],
#        [ 8.68073647,  3.36814438],
#        [ 4.71188496,  1.98874242],
#        [ 5.55840236,  1.39864026],
#        [ 0.69134624,  0.87458585],
#        [ 2.49919863, -1.6221691 ],
#        [ 2.00620679,  3.62869808],
#        [ 4.50426429, -2.61517165],
#        [ 0.69021346,  2.1831556 ],
#        [ 6.20857664,  1.04757017],
#        [-1.14652642,  0.23441211],
#        [ 7.27607541,  4.00390101],
#        [ 7.42157416,  2.53306117],
#        [ 2.68042061,  1.5597506 ],
#        [ 2.11773373,  2.7599702 ],
#        [ 0.86801586,  2.22324155],
#        [ 4.08588002, -1.31410667],
#        [ 0.86993675,  0.43007727],
#        [ 7.97892817,  3.51216845],
#        [ 3.65552578, -3.30749964],
#        [ 3.82732495, -0.25680625],
#        [ 4.43789852,  3.50835821],
#        [ 1.71539892,  3.49469661],
#        [ 6.31948057,  5.63573029],
#        [-2.12565509,  1.60315525],
#        [ 0.62178471,  1.78810105],
#        [ 2.49646122,  1.35199209],
#        [ 3.86830858,  1.98576209],
#        [ 4.01377054, -2.79708861],
#        [ 4.44226457, -1.46848777],
#        [-0.295352  ,  3.31800446],
#        [ 3.87268655, -3.98545823],
#        [ 7.2938388 ,  1.99021021],
#        [-1.3114727 ,  3.36870775],
#        [ 9.42459601,  3.61805022],
#        [ 7.85533894,  1.85940666],
#        [ 4.0041996 , -2.22967192],
#        [ 2.41379453, -2.30959447],
#        [ 5.03684039,  3.25314993],
#        [-0.01224206,  3.13847561],
#        [ 3.33933024, -2.22027635],
#        [ 9.20581486,  3.46486329],
#        [ 2.25384591,  1.90029024],
#        [-1.12860188,  4.33677368],
#        [ 4.82373554, -1.3653796 ],
#        [ 4.19018754, -2.77863475],
#        [ 4.28580913, -0.43481082],
#        [ 7.29131927,  2.30263305],
#        [ 0.30958022,  0.51743441],
#        [ 6.15946856,  3.76184694],
#        [ 1.95423287,  3.67654336],
#        [ 0.45849267,  1.24189715],
#        [ 2.62277342,  3.99556493],
#        [ 2.49992124, -3.07659245],
#        [-2.92128661,  3.4543922 ],
#        [ 2.05060892,  2.76769498],
#        [-0.22044337,  2.09791324],
#        [ 2.28274715,  2.64417001],
#        [ 8.92235684,  2.54587021],
#        [ 6.79774757,  1.05911414],
#        [ 2.0737119 ,  4.03035224],
#        [-0.39075906,  3.11949236],
#        [ 7.41612268,  1.81862877],
#        [ 3.59419028, -0.02264509],
#        [ 3.05521138, -1.54503876],
#        [ 6.93486926,  1.25341915],
#        [-1.26333051,  2.34539011],
#        [-0.05054205,  4.47289417],
#        [ 3.06484055, -2.72212843],
#        [ 4.14529954, -2.5594386 ],
#        [ 3.9125645 , -1.89018016],
#        [-0.58611887,  2.08111142],
#        [ 7.04592925,  3.22226339],
#        [ 0.68124211,  2.80719945],
#        [-0.0109379 ,  2.68646447],
#        [ 8.10356911,  3.59552439],
#        [ 0.39652314,  2.26196672],
#        [ 3.86105478, -0.80295899],
#        [ 6.97883628,  3.58397346],
#        [ 2.53956218,  1.80866579],
#        [ 1.84060561,  4.45254843],
#        [ 2.90934258,  4.04547567],
#        [-3.24078777,  1.71120969],
#        [ 7.56453587,  2.23004231],
#        [ 0.42814976,  1.42081089],
#        [-2.17308781, -0.53607912],
#        [-1.19839859,  0.95071028],
#        [ 0.47499163,  2.92422291],
#        [ 2.55119523, -1.89340382],
#        [-1.87368097,  0.30790346],
#        [ 2.25710925,  2.61123636],
#        [ 9.2474046 ,  3.52003762],
#        [ 7.21820313,  3.26081664],
#        [ 3.32864503, -0.67439389],
#        [ 1.79700247,  1.50513314],
#        [-0.62678501,  2.29907048],
#        [ 0.41179104,  2.60781266],
#        [ 0.51205101,  1.06855412],
#        [ 8.21674902,  1.91260936],
#        [-0.0367679 ,  2.49874613],
#        [ 3.83647422, -0.98725508],
#        [ 1.3270638 ,  2.14650381],
#        [ 1.5674577 ,  2.8038256 ],
#        [ 5.11862523,  2.99662512],
#        [ 2.9273641 ,  3.55304058],
#        [ 1.39730736,  2.9257867 ],
#        [ 7.50712513,  3.41400076],
#        [ 6.78842432,  5.49330169],
#        [-1.27746159,  4.27250615],
#        [ 0.86577427,  5.44673583],
#        [ 5.79305053, -0.34716206],
#        [ 1.91778398,  0.76627059],
#        [ 3.12032058, -1.60755251],
#        [ 3.50389599, -1.62157244],
#        [ 2.58101524, -1.97811747],
#        [ 3.3798209 ,  0.6909235 ],
#        [ 5.88317014,  1.5048053 ],
#        [ 2.25585112,  4.00404859],
#        [ 4.19899756,  0.83878046],
#        [ 2.93513032, -3.5742744 ],
#        [ 4.69727469, -1.43737381],
#        [ 2.89958999, -1.55624345],
#        [ 0.28117266,  0.54306388],
#        [ 8.35199293,  2.27859086],
#        [-0.78024923,  3.80751309],
#        [ 2.889534  ,  4.30203958],
#        [ 6.70282658,  0.68441983],
#        [ 3.45191373, -1.25547741],
#        [ 0.74023927,  3.26251643],
#        [ 3.68252676, -1.13799994],
#        [ 5.24666396,  4.13322747],
#        [ 0.28384919,  4.27186673],
#        [ 2.68057017, -2.08065995],
#        [ 1.43450029,  2.7885438 ],
#        [ 5.84352971,  3.2514771 ],
#        [ 4.12740634, -2.83193876],
#        [-0.34622865,  1.19292883],
#        [ 8.44223493,  3.25873223],
#        [ 8.08879616,  4.04892533],
#        [ 7.72575951,  2.83718316],
#        [ 5.09015698, -1.07678779],
#        [ 1.53365816,  1.37837164],
#        [ 0.7210238 ,  1.86133745],
#        [ 0.20547975,  0.77906502],
#        [-2.33146809,  0.81170213],
#        [-0.54530763,  1.26119551],
#        [ 8.16001293,  2.30404577],
#        [ 8.61628238,  2.85812688],
#        [ 0.54255764,  2.49766838],
#        [ 3.701012  , -3.91435433],
#        [ 3.77452407, -1.28887183],
#        [ 1.1632654 ,  2.51829216],
#        [ 3.06810722, -1.22786835],
#        [ 3.10692048, -4.64867144],
#        [ 4.06915053,  0.56207179],
#        [ 6.71171519,  2.2051909 ],
#        [-1.36572032,  4.13743819],
#        [-0.78016133,  2.64623833],
#        [ 2.05544244,  2.78121128],
#        [ 2.2231598 ,  1.22935472],
#        [ 3.34464292,  1.73553529],
#        [ 7.6957267 ,  1.52047579],
#        [ 8.79602312,  3.38011855],
#        [-2.17208159,  1.30033969],
#        [ 3.18492334, -2.06127605],
#        [ 3.82004586, -1.54354007],
#        [-0.78778642,  1.89400703],
#        [-2.94432767,  1.82310841],
#        [ 3.08234468, -3.40417961],
#        [ 3.26163747, -2.43706983],
#        [-1.5361028 ,  1.85986636],
#        [ 3.76625062,  4.05438501],
#        [ 0.66823514,  2.5377475 ],
#        [ 8.0799425 ,  1.55283142],
#        [ 4.73625321, -0.30172474],
#        [ 0.89527098,  1.41726995],
#        [ 5.37344382, -2.28058494],
#        [ 3.42522309,  3.90660776],
#        [ 7.53721978,  3.99526113],
#        [ 3.00706966, -2.97704716],
#        [ 7.75365354,  1.93706882],
#        [ 5.58415935, -0.86391992],
#        [ 2.68099931,  4.18607437],
#        [ 4.65183026,  2.63296843],
#        [ 0.52251998,  2.74863872],
#        [ 0.434543  ,  4.11130697],
#        [ 0.13929736,  3.20417279],
#        [ 3.89656282, -2.37451871],
#        [-0.07790628,  3.36407539],
#        [ 6.40990397,  2.64162712],
#        [ 0.1799495 ,  2.26889431],
#        [ 1.38913969,  3.22934165],
#        [ 4.27412575, -0.85803088],
#        [ 1.22739844,  3.93594602],
#        [ 1.09591477,  3.06503115],
#        [ 3.69571327, -2.13518688],
#        [ 8.83816432,  2.05065451],
#        [ 6.68433338,  3.00670981],
#        [ 2.00326547,  2.52941571],
#        [ 5.98247088,  2.12069259],
#        [ 3.30773058,  3.49785912],
#        [ 3.68612671,  3.80839783],
#        [ 5.49723985, -1.31365094],
#        [ 5.51981721, -1.05394179],
#        [-1.72132715,  1.12647776],
#        [ 0.74992651,  4.1827637 ],
#        [ 7.77820948,  2.28540531],
#        [ 2.78482207, -3.09407653],
#        [-0.77060224,  3.26521956],
#        [-1.31696082,  2.86729027],
#        [-1.11744856,  3.0013913 ],
#        [ 3.24834648, -1.07911572],
#        [ 5.77814821,  2.68111953],
#        [-0.11718927,  0.76943341],
#        [ 4.3672927 , -1.32094491],
#        [ 2.96235551,  3.81673836],
#        [ 2.63371073, -1.55660114],
#        [ 0.99796713,  2.78165515],
#        [-0.83535815,  1.38394118],
#        [-0.62502222,  1.76228434],
#        [ 2.4197326 ,  2.22687476],
#        [ 7.89101903,  1.37446544],
#        [ 7.59864533,  2.36233808],
#        [ 2.2253008 ,  2.63739065],
#        [ 1.65131131,  1.75137484],
#        [-0.30064797,  3.01230861],
#        [ 3.35874712,  2.46566287],
#        [ 0.50464998,  1.30288343],
#        [ 7.03823611,  3.57320218],
#        [ 6.12071007,  4.24435471],
#        [ 8.76365291,  2.67111952],
#        [-1.18326115,  0.91472891],
#        [-1.59778726,  3.15989063],
#        [ 7.74812224,  1.62971669],
#        [ 0.08964311,  3.12696019],
#        [ 0.82261186,  1.69048305],
#        [ 4.09602467, -0.87912671],
#        [ 1.62118392,  2.99690113],
#        [ 1.18297112,  0.50140971],
#        [ 2.52415556,  2.90274837],
#        [ 2.56770968,  1.71677959],
#        [ 5.14912448, -0.23729725],
#        [ 2.35011666,  2.71050182],
#        [ 1.01629217,  2.33508349],
#        [ 0.90304274,  1.96547784],
#        [ 2.91430606,  2.41382273],
#        [ 3.52440598, -1.97253132],
#        [ 0.37222138,  1.68933356],
#        [ 4.048198  ,  2.1181786 ],
#        [ 0.078026  ,  3.23493369],
#        [ 2.90873881,  1.99978777],
#        [ 7.46021774,  2.08302052],
#        [ 8.9994351 ,  1.73746234],
#        [ 5.04178393, -1.64317506],
#        [-1.12577262,  1.52179118],
#        [ 1.00853745,  2.49311739],
#        [ 0.50044626,  1.40245578],
#        [ 2.18185215,  2.0586905 ],
#        [ 7.55669396,  3.44446876],
#        [-1.13648535,  0.64993953],
#        [-3.52525405,  1.15927216],
#        [ 0.88666833, -2.86786707],
#        [-0.82803785,  1.93693781],
#        [ 0.12326628,  5.28479001],
#        [-0.68721176,  2.16993905],
#        [ 6.06334893,  2.64859473],
#        [-0.64542569,  2.7196023 ],
#        [ 1.27286719,  2.59183918],
#        [ 0.95680815,  2.8946651 ],
#        [ 7.248707  ,  1.81003836],
#        [ 2.76150522, -0.85815743],
#        [ 3.95242532,  3.55907709],
#        [ 6.06022677,  0.87260411],
#        [ 6.97430047,  3.1597031 ],
#        [ 7.58697477,  2.96651381],
#        [ 3.60826861, -1.74150166],
#        [ 2.57405546,  3.46030184],
#        [ 0.94949152,  2.48519133],
#        [ 2.2281445 ,  2.02736839],
#        [ 4.20869994, -0.92033472],
#        [ 7.60606849,  2.38109337],
#        [-0.04375564,  0.2377401 ],
#        [ 3.9422727 , -1.68489849],
#        [ 3.73237206, -2.66189517],
#        [ 4.15579913,  0.09325661],
#        [ 0.15121162,  3.33471732],
#        [ 2.67544831, -2.24046642],
#        [ 1.49263058,  3.63428188],
#        [ 2.18442878,  2.94096294],
#        [ 7.86034314,  2.89264532],
#        [ 6.82243379, -0.04880073],
#        [-0.81533676,  0.16227019]])

# %%
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.plot(X,Y,'ro')

# %% [markdown]
# # EM Algorithm

# %%
K = 3 # number of clusters

# %%
w = np.random.uniform(0,1,K)
total = np.sum(w)
w = [x/total for x in w]
w
# Out:
# [0.3711535012165064, 0.2012497459178233, 0.4275967528656703]

# %%
means = np.random.uniform(0,1,(K,final_dataset.shape[1]))

# %%
co_var_matrices = np.random.uniform(0,1,(K,final_dataset.shape[1],final_dataset.shape[1]))

# %%
def gaussian_likelihood(x,mean,co_var_matrix):
    inv = np.linalg.inv(co_var_matrix)
    det = abs(np.linalg.det(co_var_matrix))
    d = (1/sqrt(pow((2*3.1416),final_dataset.shape[1])*det))
    likelihood = []
    
    for i in x:
        a = np.dot(inv,i-mean)
        b = np.dot((i-mean),a)
        c = np.exp(-0.5*b)
        l = c*d
        likelihood.append(l)

    return likelihood

# %%
def EM_Alogrithm(x,means,co_var_matrices):
    prev = 0 
    
    while(True):
        class_wise_likelihood = []
        for i in range(K):
            class_wise_likelihood.append(gaussian_likelihood(x,means[i],co_var_matrices[i]))

        likelihood = np.array(class_wise_likelihood).transpose()

        p = []

        for k in range(K):
            p_k = []
            for i in range(len(likelihood)):
                t = 0
                for j in range(len(w)):
                    t += w[j]*likelihood[i][j]
                p_k.append( (w[k]*likelihood[i][k]) / t )
            p.append(p_k)

        p = np.array(p)

        for k in range(K):
            sum_arr = 0 
            for i in range(len(x)):
                sum_arr += p[k][i]*x[i]
            means[k] = sum_arr / np.sum(p[k])


        for k in range(K):
            co_var_matrix = 0
            for i in range(len(x)):
                arr = np.array(x[i]).reshape(2,1)
                cross = p[k][i]*arr*arr.transpose()
                co_var_matrix += cross
            sum_p_k = np.sum(p[k])
            co_var_matrices[k] = co_var_matrix/sum_p_k

        for k in range(K):
            w[k] = np.sum(p[k])/len(x)
        
        class_wise_likelihood = []
        for i in range(K):
            class_wise_likelihood.append(gaussian_likelihood(x,means[i],co_var_matrices[i]))

        likelihood = np.array(class_wise_likelihood).transpose()
        
        log_likelihood = 0
        
        for i in range(len(likelihood)):
            t = 0
            for j in range(len(w)):
                t += w[j]*likelihood[i][j]
            log_likelihood += np.log(t)
        
        
        diff = abs(prev-log_likelihood)
        
        if(diff<1e-2):
            print(w)
            break
        
        prev = log_likelihood
    return w,means,co_var_matrices

# %%
w,means,co_var_matrices = EM_Alogrithm(final_dataset,means,co_var_matrices)
# Out:
# [0.47928488502977856, 0.2238336265592038, 0.29688148841101764]

# %%
class_wise_likelihood = []
for i in range(K):
    class_wise_likelihood.append(gaussian_likelihood(final_dataset,means[i],co_var_matrices[i]))

likelihood = np.array(class_wise_likelihood).transpose()

index = []

for i in range(len(final_dataset)):
    index.append(np.argmax(likelihood[i]))

index = np.array(index)

# %%
class_wise_dataset = []

for k in range(K):
    class_wise_dataset.append(np.array(final_dataset[np.where(index==k)]))

# %%
colors = ['ro','go','bo']

plt.title('EM Algorithm')
plt.xlabel('PC1')
plt.ylabel('PC2')

for k in range(K):
    arr = class_wise_dataset[k].transpose()
    X = arr[0]
    Y = arr[1]
    plt.plot(X,Y,colors[k])
